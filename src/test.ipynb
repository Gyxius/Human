# %%
import pickle

# %%
with open('../q_table.pkl', 'rb') as f:
    saved_q_tables = pickle.load(f)

# %%
saved_q_tables[(0, 0, 3, 3)]
# Out:
# [30.24677111615503,
#  33.65443816396794,
#  214.77068377436444,
#  104.1778708827039,
#  -2.6085155,
#  -2.71]

# %%
saved_q_tables
# Out:
# {(4, 3, 3, 1): [465.41770140250077,
#   598.7556451971086,
#   364.0285250212737,
#   361.56570666186855,
#   378.4958914184941,
#   457.5366520860546],
#  (4, 3, 2, 1): [795.4639758828109,
#   792.6808425909416,
#   692.3548619279995,
#   601.2286153725945,
#   706.19609665114,
#   697.7855258799084],
#  (3, 3, 1, 1): [774.7891102331166,
#   813.5767668990031,
#   754.4567091847483,
#   744.6473743536287,
#   753.8597950528593,
#   746.9137880561453],
#  (3, 3, 0, 1): [767.7117034770138,
#   902.0413470705666,
#   879.14496761007,
#   779.3556679331194,
#   1064.8785481551427,
#   885.6846480200476],
#  (2, 3, 1, 1): [715.5688745947505,
#   983.364198269,
#   754.8901546800345,
#   770.5987048964279,
#   765.3555963574556,
#   758.9309654848406],
#  (1, 3, 2, 1): [609.0175663815759,
#   708.7181988575564,
#   677.6405252571465,
#   776.5672298461649,
#   687.8846668040908,
#   686.4043855288367],
#  (1, 3, 1, 0): [814.0321132197424,
#   771.9957576915431,
#   907.6008248251306,
# ...

# %%
bb

# %%
98 // 5
# Out:
# 19
