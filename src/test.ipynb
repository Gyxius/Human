# %%
import pickle

# %%
with open('../q_table.pkl', 'rb') as f:
    saved_q_tables = pickle.load(f)

# %%
saved_q_tables
# Out:
# [{(100, 0, 0, 100, 0.0, -258, 116, 100, 282.8780656042458): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -253, 116, 100, 278.32534918688236): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -248, 116, 100, 273.7882393383616): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -243, 116, 100, 269.2675249635574): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -238, 116, 100, 264.76404589747455): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -233, 116, 100, 260.2786967848118): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -228, 116, 100, 255.8124312851117): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -223, 116, 100, 251.3662666309861): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
#   (100, 0, 0, 100, 0.0, -218, 116, 100, 246.94128856876083): [-0.2,
#    0,
#    0,
#    0,
#    0,
#    0],
# ...
